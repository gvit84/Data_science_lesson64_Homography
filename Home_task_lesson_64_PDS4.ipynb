# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im_src = cv2.imread('chess_1.png')

# %%
plt.figure(figsize=(12,8))
plt.imshow(im_src)
plt.show()

# %%
pts_src = np.array([[210, 79], [447, 72], [214, 219], [443, 230]])

# %%
im_dst = cv2.imread('chess_2.png')
plt.figure(figsize=(12,8))
plt.imshow(im_dst)
plt.show()

# %%
pts_dst = np.array([[222, 312], [217, 67], [382, 347], [471, 115]])

# %%
h, status = cv2.findHomography(pts_dst, pts_src)
h
# Out:
# array([[ 3.44793485e-01, -1.25059188e+00,  4.69487630e+02],
#        [ 7.20366105e-01, -7.81675564e-02, -7.69047969e+01],
#        [ 5.05637758e-04, -1.18628992e-03,  1.00000000e+00]])

# %%
im_out = cv2.warpPerspective(im_src, h,
                            (im_dst.shape[1],
                            im_dst.shape[0]))

# %%
plt.figure(figsize=(12,6))
cv2.imwrite('result.jpg', im_out)
plt.imshow(im_out)
plt.show()
